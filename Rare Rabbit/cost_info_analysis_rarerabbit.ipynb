# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('processed csv/rarerabbit_price_info.csv')
df.head()
# Out:
#          Brand                                              Title    SP   MRP  \
# 0  Rare Rabbit  Men Typography Round Neck Cotton Blend Black T...  1149  2299
# 1  Rare Rabbit  Men Printed Round Neck Cotton Blend White T-Shirt  1149  2299
# 2  Rare Rabbit  Men Printed Round Neck Cotton Blend Green T-Shirt  1149  2299
# 3  Rare Rabbit     Men Solid Crew Neck Cotton Blend Black T-Shirt  1169  1799
# 4  Rare Rabbit      Men Solid Polo Neck Pure Cotton White T-Shirt  1749  3499
#
#    Discount
# 0        50
# 1        50
# 2        50
# 3        35
# 4        50

# %%
df.describe()
# Out:
#                 SP         MRP    Discount
# count   400.000000   400.00000  400.000000
# mean   1404.615000  2246.50000   37.540000
# std     571.165209   622.98799   15.252212
# min     749.000000  1299.00000    0.000000
# 25%    1079.000000  1799.00000   32.000000
# 50%    1169.000000  1999.00000   40.000000
# 75%    1599.000000  2499.00000   50.000000
# max    3798.000000  4399.00000   55.000000

# %%
def categorize_tshirt(name):
    categories = []

    if 'Typography Round Neck' in name:
        categories.append('Typography Round')
    if 'Printed Round Neck' in name:
        categories.append('Printed Round')
    if 'Solid Round Neck' in name:
        categories.append('Solid Round')
    if 'Solid Crew Neck' in name:
        categories.append('Solid Crew')
    if 'Graphic Print Crew Neck' in name:
        categories.append('Graphic Print Crew')
    if 'Solid Polo Neck' in name:
        categories.append('Solid Polo')  
    if 'Printed Polo Neck' in name:
        categories.append('Printed Polo') 
    if 'Solid Mandarin Collar' in name:
        categories.append('Solid Mandarin Collar') 
    if 'Solid Mandarin Collar' in name:
        categories.append('Solid Mandarin Collar')
    if not categories:
        categories.append('Other')

    return ', '.join(sorted(set(categories)))

# Apply the categorization function to each T-shirt name
df['Category'] = df['Title'].apply(categorize_tshirt)

# %%
df.head(40)
# Out:
#           Brand                                              Title    SP  \
# 0   Rare Rabbit  Men Typography Round Neck Cotton Blend Black T...  1149
# 1   Rare Rabbit  Men Printed Round Neck Cotton Blend White T-Shirt  1149
# 2   Rare Rabbit  Men Printed Round Neck Cotton Blend Green T-Shirt  1149
# 3   Rare Rabbit     Men Solid Crew Neck Cotton Blend Black T-Shirt  1169
# 4   Rare Rabbit      Men Solid Polo Neck Pure Cotton White T-Shirt  1749
# 5   Rare Rabbit     Men Solid Polo Neck Cotton Blend White T-Shirt  1644
# 6   Rare Rabbit   Men Printed Round Neck Pure Cotton Green T-Shirt  1199
# 7   Rare Rabbit  Men Solid Round Neck Cotton Blend Navy Blue T-...  1124
# 8   Rare Rabbit      Men Solid Round Neck Pure Cotton Pink T-Shirt  1079
# 9   Rare Rabbit    Men Solid High Neck Viscose Rayon White T-Shirt  1819
# 10  Rare Rabbit    Men Solid Round Neck Cotton Blend White T-Shirt  1399
# 11  Rare Rabbit  Men Typography Round Neck Pure Cotton Blue T-S...   985
# 12  Rare Rabbit  Men Printed Round Neck Cotton Blend Black T-Shirt  1149
# 13  Rare Rabbit  Men Graphic Print Crew Neck Pure Cotton Black ...  3798
# 14  Rare Rabbit    Men Solid High Neck Viscose Rayon Black T-Shirt  1819
# 15  Rare Rabbit       Men Solid Polo Neck Pure Cotton Pink T-Shirt  1649
# 16  Rare Rabbit  Men Printed Round Neck Cotton Blend Navy Blue ...  1149
# 17  Rare Rabbit  Men Printed Round Neck Cotton Blend Green T-Shirt  1149
# 18  Rare Rabbit    Men Solid Round Neck Cotton Blend Brown T-Shirt  1151
# 19  Rare Rabbit    Men Printed Round Neck Pure Cotton Blue T-Shirt  1149
# 20  Rare Rabbit  Men Graphic Print Round Neck Pure Cotton Navy ...  1079
# 21  Rare Rabbit  Men Printed Round Neck Cotton Blend White T-Shirt  1149
# 22  Rare Rabbit   Men Printed Round Neck Pure Cotton Green T-Shirt  1149
# 23  Rare Rabbit    Men Printed Polo Neck Pure Cotton Black T-Shirt  1849
# 24  Rare Rabbit  Men Printed, Typography Round Neck Cotton Blen...  1169
# 25  Rare Rabbit  Men Solid Mandarin Collar Pure Cotton Green T-...  1737
# 26  Rare Rabbit      Men Solid Polo Neck Pure Cotton Green T-Shirt  1624
# 27  Rare Rabbit  Men Printed Round Neck Pure Cotton Dark Blue T...   899
# 28  Rare Rabbit  Men Printed Round Neck Cotton Blend Black T-Shirt  1249
# 29  Rare Rabbit   Men Printed Round Neck Pure Cotton Green T-Shirt   953
# 30  Rare Rabbit  Men Graphic Print Round Neck Pure Cotton Grey ...   999
# 31  Rare Rabbit   Men Printed Round Neck Pure Cotton Black T-Shirt  1079
# 32  Rare Rabbit   Men Printed Round Neck Cotton Blend Pink T-Shirt  1149
# 33  Rare Rabbit  Men Printed Round Neck Cotton Blend Maroon T-S...  1259
# 34  Rare Rabbit  Men Self Design Polo Neck Cotton Blend Brown T...  2099
# 35  Rare Rabbit    Men Solid Round Neck Cotton Blend Green T-Shirt  1954
# 36  Rare Rabbit  Men Typography Round Neck Cotton Blend Maroon ...  1094
# 37  Rare Rabbit  Men Solid Polo Neck Cotton Blend Light Blue T-...  2267
# 38  Rare Rabbit  Men Printed Round Neck Cotton Blend Black T-Shirt  1079
# 39  Rare Rabbit  Men Printed Round Neck Pure Cotton Navy Blue T...  1199
#
#      MRP  Discount               Category
# 0   2299        50       Typography Round
# 1   2299        50          Printed Round
# 2   2299        50          Printed Round
# 3   1799        35             Solid Crew
# 4   3499        50             Solid Polo
# 5   3499        53             Solid Polo
# 6   1999        40          Printed Round
# 7   1499        25            Solid Round
# 8   1799        40            Solid Round
# 9   2799        35                  Other
# 10  2799        50            Solid Round
# 11  1699        42       Typography Round
# 12  2299        50          Printed Round
# 13  3799         0     Graphic Print Crew
# 14  2799        35                  Other
# 15  3299        50             Solid Polo
# 16  2299        50          Printed Round
# 17  2299        50          Printed Round
# 18  1799        36            Solid Round
# 19  2299        50          Printed Round
# 20  1799        40                  Other
# 21  2299        50          Printed Round
# 22  2299        50          Printed Round
# 23  3699        50           Printed Polo
# 24  1799        35       Typography Round
# 25  2199        21  Solid Mandarin Collar
# 26  2499        35             Solid Polo
# 27  1799        50          Printed Round
# 28  2499        50          Printed Round
# 29  1799        47          Printed Round
# 30  1999        50                  Other
# 31  1799        40          Printed Round
# 32  2299        50          Printed Round
# 33  1799        30          Printed Round
# 34  4199        50                  Other
# 35  2299        15            Solid Round
# 36  1499        27       Typography Round
# 37  4199        46             Solid Polo
# 38  1799        40          Printed Round
# 39  1999        40          Printed Round

# %% [markdown]
# Categories

# %%
for i in df['Category'].unique():
    print(i)
# Out:
# Typography Round
# Printed Round
# Solid Crew
# Solid Polo
# Solid Round
# Other
# Graphic Print Crew
# Printed Polo
# Solid Mandarin Collar

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Brand     400 non-null    object
#  1   Title     400 non-null    object
#  2   SP        400 non-null    int64
#  3   MRP       400 non-null    int64
#  4   Discount  400 non-null    int64
#  5   Category  400 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 18.9+ KB

# %%
cols = ['MRP', 'SP','Discount']

# Initialize an empty list to store category statistics
category_stats = []

# Compute mean, min, and max for each category and each column
for i in df['Category'].unique():
    cat = df[df['Category'] == i]
    stats = {
        'Category': i,
        'MRP_min': cat['MRP'].min(),
        'MRP_max': cat['MRP'].max(),
        'SP_min': cat['SP'].min(),
        'SP_max': cat['SP'].max(),
        'Discount_avg': cat['Discount'].mean(),
    }
    category_stats.append(stats)

# Convert the list of dictionaries to a DataFrame
category_stats_df = pd.DataFrame(category_stats)
category_stats_df
# Out:
#                 Category  MRP_min  MRP_max  SP_min  SP_max  Discount_avg
# 0       Typography Round     1499     3199     985    1599     42.052632
# 1          Printed Round     1499     2999     881    1839     43.981308
# 2             Solid Crew     1799     2899    1079    1954     26.750000
# 3             Solid Polo     1799     4199    1259    2449     38.948718
# 4            Solid Round     1299     2999     749    1954     38.382353
# 5                  Other     1299     4399     809    3398     39.879121
# 6     Graphic Print Crew     1799     3799     899    3798      6.972222
# 7           Printed Polo     3199     3999    1439    1999     52.000000
# 8  Solid Mandarin Collar     2199     3199    1249    2879     31.222222

# %%
# Plot min and max MRP and SP
plt.figure(figsize=(14, 10))

# MRP
plt.figure(figsize=(10, 6))
bar_width = 0.4
index = np.arange(len(category_stats_df))

plt.bar(index, category_stats_df['MRP_min'], bar_width, color='orange', label='Min MRP')
plt.bar(index + bar_width, category_stats_df['MRP_max'], bar_width, color='pink', label='Max MRP')

plt.xlabel('Category')
plt.ylabel('MRP')
plt.title('Min and Max MRP by Category (Rare Rabbit)')
plt.xticks(index + bar_width / 2, category_stats_df['Category'], rotation=90)
plt.legend()
plt.show()

# SP
plt.figure(figsize=(10, 6))
bar_width = 0.4
index = np.arange(len(category_stats_df))

plt.bar(index, category_stats_df['SP_min'], bar_width, color='orange', label='Min SP')
plt.bar(index + bar_width, category_stats_df['SP_max'], bar_width, color='pink', label='Max SP')

plt.xlabel('Category')
plt.ylabel('SP')
plt.title('Min and Max SP by Category (Rare Rabbit)')
plt.xticks(index + bar_width / 2, category_stats_df['Category'], rotation=90)
plt.legend()
plt.show()


# Plot average discount for each category
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Discount_avg', data=category_stats_df)
plt.xticks(rotation=90)
plt.ylabel('Average Discount')
plt.title('Average Discount by Category (Rare Rabbit)')
plt.show()

# # Plot average rating for each category
# plt.figure(figsize=(12, 6))
# sns.barplot(x='Category', y='Rating_avg', data=category_stats_df)
# plt.ylim(4.4,4.6)
# plt.xticks(rotation=90)
# plt.ylabel('Average Rating')
# plt.title('Average Rating by Category')
# plt.show()

# %%
category_stats_df
# Out:
#                 Category  MRP_min  MRP_max  SP_min  SP_max  Discount_avg
# 0       Typography Round     1499     3199     985    1599     42.052632
# 1          Printed Round     1499     2999     881    1839     43.981308
# 2             Solid Crew     1799     2899    1079    1954     26.750000
# 3             Solid Polo     1799     4199    1259    2449     38.948718
# 4            Solid Round     1299     2999     749    1954     38.382353
# 5                  Other     1299     4399     809    3398     39.879121
# 6     Graphic Print Crew     1799     3799     899    3798      6.972222
# 7           Printed Polo     3199     3999    1439    1999     52.000000
# 8  Solid Mandarin Collar     2199     3199    1249    2879     31.222222

# %%
category_counts = df['Category'].value_counts()

plt.figure(figsize=(16, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title('T-shirt Category Distribution (Rare Rabbit)')
plt.legend(loc='upper right', bbox_to_anchor=(0.05, 1),title="Category")
plt.show()
