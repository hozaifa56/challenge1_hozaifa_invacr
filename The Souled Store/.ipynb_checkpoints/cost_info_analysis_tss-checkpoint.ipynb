# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('processed csv/tss_tshirt_info.csv')
df.head()
# Out:
#                             Title              Series  MRP    SP  Discount
# 0        Deadpool: Kill For Tacos            T-Shirts  NaN   799         0
# 1          Harry Potter: Hogwarts        Zipper Polos  NaN  1299         0
# 2                Naruto: Yin-Yang  Oversized T-Shirts  NaN   899         0
# 3           Naruto: Itachi Uchiha  Oversized T-Shirts  NaN  1049         0
# 4  Baki Hanma: You Shouldn't Have  Oversized T-Shirts  NaN  1299         0

# %%
df.describe()
# Out:
#                MRP           SP     Discount
# count   326.000000  1092.000000  1092.000000
# mean    981.365031   857.468864     9.254579
# std     284.692717   274.042762    15.049482
# min     449.000000   249.000000     0.000000
# 25%     899.000000   699.000000     0.000000
# 50%     999.000000   849.000000     0.000000
# 75%     999.000000   999.000000    21.000000
# max    2997.000000  2847.000000    57.000000

# %%
for i in df['Series'].unique():
    print(i)
# Out:
# T-Shirts
# Zipper Polos
# Oversized T-Shirts
# Oversized Polos
# Polos
# Hooded T-Shirts
# Oversized Full Sleeve T-Shirts
# Drop Cut T-Shirts
# Supima T-Shirts
# Men Full Sleeve T-Shirts
# Men Rugby Polos
# Men Relaxed Fit T-Shirts
# Mandarin Polos
# Jerseys
# Henley T-Shirts
# Oversized Jerseys
# Super Oversized T-Shirts
# Supima Full Sleeve Henley T-Shirts
# Performance Jerseys
# Supima Drop Cut T-Shirts
# Men Co-ord Sets
# Men Performance Essential T-Shirts
# Men Performance Essential Drop Cut T-Shirts
# Bomber Neck Polos
# Easy Fit Full Sleeve T-Shirts
# Jackets
# Half Sleeve Henley T-Shirts
# Unisex T-Shirts

# %%
def categorize_tshirt(name):
    categories = []

    if 'Zipper Polos' in name:
        categories.append('Zipper Polos')
    if 'Oversized T-Shirts' in name:
        categories.append('Oversized T-Shirts')
    if 'Oversized Polos' in name:
        categories.append('Oversized Polos')
    if 'T-Shirts' in name:
        categories.append('Round Neck')
    if 'Full Sleeve' in name:
        categories.append('Full Sleeve Tshirt')  
        
    if 'Supima T-Shirts' in name:
        categories.append('Supima T-Shirts')  
    if 'Polos' in name:
        categories.append('Polos')  
    if 'Full Sleeve' in name:
        categories.append('Full Sleeve Tshirt')
    if not categories:
        categories.append('Other')

    return ', '.join(sorted(set(categories)))

# Apply the categorization function to each T-shirt name
df['Category'] = df['Series'].apply(categorize_tshirt)

# %%
df.head(40)
# Out:
#                                  Title                          Series    MRP  \
# 0             Deadpool: Kill For Tacos                        T-Shirts    NaN
# 1               Harry Potter: Hogwarts                    Zipper Polos    NaN
# 2                     Naruto: Yin-Yang              Oversized T-Shirts    NaN
# 3                Naruto: Itachi Uchiha              Oversized T-Shirts    NaN
# 4       Baki Hanma: You Shouldn't Have              Oversized T-Shirts    NaN
# 5              Harry Potter: Slytherin                        T-Shirts    NaN
# 6                  Deadpool: Anti-Hero              Oversized T-Shirts    NaN
# 7              Transformers: Bumblebee              Oversized T-Shirts    NaN
# 8            Baki Hanma: The Strongest              Oversized T-Shirts    NaN
# 9       Black Panther: Wakanda Forever                    Zipper Polos    NaN
# 10        Marvel: Loki God Of Mischief                    Zipper Polos    NaN
# 11                 Punisher: It's Time                        T-Shirts    NaN
# 12                     Punisher: Skull                    Zipper Polos    NaN
# 13                 Solids: Regal Black                 Oversized Polos    NaN
# 14              Superman: Man Of Steel                           Polos    NaN
# 15              TSS Originals: Cadmium                    Zipper Polos    NaN
# 16                 TSS Originals: Kale                 Hooded T-Shirts    NaN
# 17                       Top Gun: 1986                           Polos    NaN
# 18           Jungle Book: Jungle Tales              Oversized T-Shirts    NaN
# 19                      Solids: Yellow              Oversized T-Shirts  999.0
# 20           Harry Potter: Death Eater              Oversized T-Shirts    NaN
# 21              Punisher: Classic Logo                        T-Shirts  699.0
# 22       TSS Originals: Fusion Bandana              Oversized T-Shirts    NaN
# 23                 Punisher: Cold Fury              Oversized T-Shirts    NaN
# 24                      Naruto: Sasuke  Oversized Full Sleeve T-Shirts    NaN
# 25                 Tie-Dye: Grape Wine  Oversized Full Sleeve T-Shirts    NaN
# 26                     Batman: 3D Logo                        T-Shirts    NaN
# 27   Solids: Black & White Colourblock                           Polos    NaN
# 28             The Godfather: Corleone                        T-Shirts    NaN
# 29                 Joker: Forever Evil              Oversized T-Shirts    NaN
# 30                     DC: Batman Logo               Drop Cut T-Shirts    NaN
# 31               Solids: Electric Blue              Oversized T-Shirts    NaN
# 32               TSS Originals: Cactus              Oversized T-Shirts    NaN
# 33               TSS Originals: Poster              Oversized T-Shirts    NaN
# 34            Looney Tunes: The Coyote                        T-Shirts    NaN
# 35                The Office: I Manage                        T-Shirts    NaN
# 36       Classic Sustainable Tee: Wine                        T-Shirts    NaN
# 37           Courage: Kinda Antisocial                        T-Shirts    NaN
# 38  Harry Potter: Gryffindor Rugby Set                 Hooded T-Shirts    NaN
# 39               TSS Originals: Sphinx  Oversized Full Sleeve T-Shirts    NaN
#
#       SP  Discount                        Category
# 0    799         0                      Round Neck
# 1   1299         0             Polos, Zipper Polos
# 2    899         0  Oversized T-Shirts, Round Neck
# 3   1049         0  Oversized T-Shirts, Round Neck
# 4   1299         0  Oversized T-Shirts, Round Neck
# 5    599         0                      Round Neck
# 6   1399         0  Oversized T-Shirts, Round Neck
# 7    949         0  Oversized T-Shirts, Round Neck
# 8    999         0  Oversized T-Shirts, Round Neck
# 9    999         0             Polos, Zipper Polos
# 10   999         0             Polos, Zipper Polos
# 11   749         0                      Round Neck
# 12   999         0             Polos, Zipper Polos
# 13  1299         0          Oversized Polos, Polos
# 14  1299         0                           Polos
# 15  1049         0             Polos, Zipper Polos
# 16  1499         0                      Round Neck
# 17  1299         0                           Polos
# 18   899         0  Oversized T-Shirts, Round Neck
# 19   699        30  Oversized T-Shirts, Round Neck
# 20   999         0  Oversized T-Shirts, Round Neck
# 21   549        21                      Round Neck
# 22   949         0  Oversized T-Shirts, Round Neck
# 23  1049         0  Oversized T-Shirts, Round Neck
# 24   999         0  Full Sleeve Tshirt, Round Neck
# 25   999         0  Full Sleeve Tshirt, Round Neck
# 26   799         0                      Round Neck
# 27   999         0                           Polos
# 28   799         0                      Round Neck
# 29   999         0  Oversized T-Shirts, Round Neck
# 30   899         0                      Round Neck
# 31   699         0  Oversized T-Shirts, Round Neck
# 32   899         0  Oversized T-Shirts, Round Neck
# 33  1049         0  Oversized T-Shirts, Round Neck
# 34   649         0                      Round Neck
# 35   699         0                      Round Neck
# 36   599         0                      Round Neck
# 37   799         0                      Round Neck
# 38  1299         0                      Round Neck
# 39  1299         0  Full Sleeve Tshirt, Round Neck

# %% [markdown]
# Categories

# %%
for i in df['Category'].unique():
    print(i)
# Out:
# Round Neck
# Polos, Zipper Polos
# Oversized T-Shirts, Round Neck
# Oversized Polos, Polos
# Polos
# Full Sleeve Tshirt, Round Neck
# Round Neck, Supima T-Shirts
# Other

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1092 entries, 0 to 1091
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Title     1092 non-null   object
#  1   Series    1092 non-null   object
#  2   MRP       326 non-null    float64
#  3   SP        1092 non-null   int64
#  4   Discount  1092 non-null   int64
#  5   Category  1092 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 51.3+ KB

# %%
cols = ['MRP', 'SP','Discount']

# Initialize an empty list to store category statistics
category_stats = []

# Compute mean, min, and max for each category and each column
for i in df['Category'].unique():
    cat = df[df['Category'] == i]
    stats = {
        'Category': i,
        'MRP_min': cat['MRP'].min(),
        'MRP_max': cat['MRP'].max(),
        'SP_min': cat['SP'].min(),
        'SP_max': cat['SP'].max(),
        'Discount_avg': cat['Discount'].mean(),
    }
    category_stats.append(stats)

# Convert the list of dictionaries to a DataFrame
category_stats_df = pd.DataFrame(category_stats)
category_stats_df
# Out:
#                          Category  MRP_min  MRP_max  SP_min  SP_max  \
# 0                      Round Neck    449.0   1399.0     299    1499
# 1             Polos, Zipper Polos      NaN      NaN     999    1399
# 2  Oversized T-Shirts, Round Neck    899.0   1199.0     499    1799
# 3          Oversized Polos, Polos    999.0    999.0     599    1499
# 4                           Polos    899.0   1199.0     599    1499
# 5  Full Sleeve Tshirt, Round Neck    699.0   1299.0     399    1299
# 6     Round Neck, Supima T-Shirts    999.0   2997.0     799    2847
# 7                           Other    499.0    999.0     249    2199
#
#    Discount_avg
# 0      8.911243
# 1      0.000000
# 2      9.934426
# 3      6.953125
# 4      5.280000
# 5     13.500000
# 6      1.515152
# 7     17.947368

# %%
# Plot min and max MRP and SP
plt.figure(figsize=(14, 10))

# MRP
plt.figure(figsize=(12, 6))
bar_width = 0.4
index = np.arange(len(category_stats_df))

plt.bar(index, category_stats_df['MRP_min'], bar_width, color='orange', label='Min MRP')
plt.bar(index + bar_width, category_stats_df['MRP_max'], bar_width, color='pink', label='Max MRP')

plt.xlabel('Category')
plt.ylabel('MRP')
plt.title('Min and Max MRP by Category')
plt.xticks(index + bar_width / 2, category_stats_df['Category'], rotation=90)
plt.legend()
plt.show()

# SP
plt.figure(figsize=(12, 6))
bar_width = 0.4
index = np.arange(len(category_stats_df))

plt.bar(index, category_stats_df['SP_min'], bar_width, color='orange', label='Min SP')
plt.bar(index + bar_width, category_stats_df['SP_max'], bar_width, color='pink', label='Max SP')

plt.xlabel('Category')
plt.ylabel('SP')
plt.title('Min and Max SP by Category')
plt.xticks(index + bar_width / 2, category_stats_df['Category'], rotation=90)
plt.legend()
plt.show()


# Plot average discount for each category
plt.figure(figsize=(12, 6))
sns.barplot(x='Category', y='Discount_avg', data=category_stats_df)
plt.xticks(rotation=90)
plt.ylabel('Average Discount')
plt.title('Average Discount by Category')
plt.show()

# # Plot average rating for each category
# plt.figure(figsize=(12, 6))
# sns.barplot(x='Category', y='Rating_avg', data=category_stats_df)
# plt.ylim(4.4,4.6)
# plt.xticks(rotation=90)
# plt.ylabel('Average Rating')
# plt.title('Average Rating by Category')
# plt.show()

# %%
category_stats_df
# Out:
#                          Category  MRP_min  MRP_max  SP_min  SP_max  \
# 0                      Round Neck    449.0   1399.0     299    1499
# 1             Polos, Zipper Polos      NaN      NaN     999    1399
# 2  Oversized T-Shirts, Round Neck    899.0   1199.0     499    1799
# 3          Oversized Polos, Polos    999.0    999.0     599    1499
# 4                           Polos    899.0   1199.0     599    1499
# 5  Full Sleeve Tshirt, Round Neck    699.0   1299.0     399    1299
# 6     Round Neck, Supima T-Shirts    999.0   2997.0     799    2847
# 7                           Other    499.0    999.0     249    2199
#
#    Discount_avg
# 0      8.911243
# 1      0.000000
# 2      9.934426
# 3      6.953125
# 4      5.280000
# 5     13.500000
# 6      1.515152
# 7     17.947368

# %%
category_counts = df['Category'].value_counts()

plt.figure(figsize=(16, 6))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%')
plt.title('T-shirt Category Distribution')
plt.legend(loc='upper right', bbox_to_anchor=(0.05, 1),title="Category")
plt.show()

# %% [markdown]
# # Reviews analysis

# %%
df1=pd.read_csv('processed csv/tss_review.csv')
df1.head()
# Out:
#                Name                                              Title  \
# 0          Auro2303  Have Always been loving souled store!.. And still
# 1        mrharsh770                       The best merchandise site!!!
# 2   goyalritika2123                                    A great website
# 3  dwivedimansi2003                                            Awesome
# 4  onepieceabhiroop                     Souled Store - Is it soulful??
#
#                                                 Desc
# 0  Having a physical souled store near my place w...
# 1  The Souled Store is known for its unique desig...
# 2  A clean and intuitive interface makes shopping...
# 3  The themed collections at The Souled Store are...
# 4  The themed collections at The Souled Store are...

# %%
# Positive words and phrases
positive_words = [
    "awesome", "top notch", "loved", "care", "love", "passion", "spoiled", 
    "perfect", "well-made", "fantastic", "great deals", "best designs", 
    "creativity", "attention to detail", "amazed", "amazing", "loved", 
    "great quality", "impressive", "satisfied", "happy", "good", "beautiful", 
    "fantastic", "wonderful", "quick", "neat", "attractive", "fast", 
    "good service", "very good", "great", "recommended", "decent", 
    "huge collection", "cheaper", "satisfactory", "trust", "comfortable", 
    "perfect size", "great experience", "convenient", "high quality", 
    "well packaged", "very satisfied", "nice", "out of this world"
]


neutral_words = [
    "okay", "average", "fine", "alright", "acceptable", "standard", 
    "mediocre", "normal", "typical", "so-so", "nothing special", 
    "basic", "fair", "ordinary"
]


negative_words = [
    "pathetic", "horrible", "cheated", "scammed", "bad", "worse", "worst", 
    "inconvenienced", "disappointed", "poor", "not as expected", "not delivered", 
    "problematic", "unresponsive", "delay", "high price", "fraud", 
    "difficult", "low quality", "misleading", "overcharged", "bad condition", 
    "wasted", "cheap", "tiny", "poor quality", "bad experience", 
    "irritating", "sucks", "bad service", "messed up", "incorrect", 
    "worthless", "untrustworthy", "lack of communication"
]

# %%
def categorize_review(review):
    review=review.lower()
    positive_count = sum(word in review for word in positive_words)
    negative_count = sum(word in review for word in negative_words)
    neutral_count = sum(word in review for word in neutral_words)
    
    if positive_count > max(negative_count, neutral_count):
        return "positive"
    elif negative_count > max(positive_count, neutral_count):
        return "negative"
    else:
        return "neutral"

# Apply the function to the DataFrame
df1['sentiment'] = df1['Desc'].apply(categorize_review)

# Show the DataFrame with the new sentiment column
df1.head()
# Out:
#                Name                                              Title  \
# 0          Auro2303  Have Always been loving souled store!.. And still
# 1        mrharsh770                       The best merchandise site!!!
# 2   goyalritika2123                                    A great website
# 3  dwivedimansi2003                                            Awesome
# 4  onepieceabhiroop                     Souled Store - Is it soulful??
#
#                                                 Desc sentiment
# 0  Having a physical souled store near my place w...   neutral
# 1  The Souled Store is known for its unique desig...  positive
# 2  A clean and intuitive interface makes shopping...   neutral
# 3  The themed collections at The Souled Store are...  positive
# 4  The themed collections at The Souled Store are...  positive

# %%
category_counts = df1['sentiment'].value_counts()
print(category_counts)
# Out:
# sentiment
# positive    19
# neutral     13
# negative     9
# Name: count, dtype: int64

# %%
lab=['neutral','positive','negative']
colors = ['blue', 'green', 'red']  # Specify colors for the labels

# Create the pie chart
plt.pie(category_counts, labels=lab, autopct='%1.1f%%', colors=colors)
plt.legend(loc="upper right", bbox_to_anchor=(0.1, 0.5),title="Sentiments")
plt.title("Customer Sentiment Analysis")
plt.show()

# %%
import pandas as pd
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Sample DataFrame creation
# Assuming df_reviews is already created and contains a column 'review_text'

# Positive words and phrases
positive_words = [
    "awesome", "top notch", "loved", "care", "love", "passion", "spoiled", 
    "perfect", "well-made", "fantastic", "great deals", "best designs", 
    "creativity", "attention to detail", "amazed", "amazing", "loved", 
    "great quality", "impressive", "satisfied", "happy", "good", "beautiful", 
    "fantastic", "wonderful", "quick", "neat", "attractive", "fast", 
    "good service", "very good", "great", "recommended", "decent", 
    "huge collection", "cheaper", "satisfactory", "trust", "comfortable", 
    "perfect size", "great experience", "convenient", "high quality", 
    "well packaged", "very satisfied", "nice", "out of this world"
]


neutral_words = [
    "okay", "average", "fine", "alright", "acceptable", "standard", 
    "mediocre", "normal", "typical", "so-so", "nothing special", 
    "basic", "fair", "ordinary"
]


negative_words = [
    "pathetic", "horrible", "cheated", "scammed", "bad", "worse", "worst", 
    "inconvenienced", "disappointed", "poor", "not as expected", "not delivered", 
    "problematic", "unresponsive", "delay", "high price", "fraud", 
    "difficult", "low quality", "misleading", "overcharged", "bad condition", 
    "wasted", "cheap", "tiny", "poor quality", "bad experience", 
    "irritating", "sucks", "bad service", "messed up", "incorrect", 
    "worthless", "untrustworthy", "lack of communication"
]


# Combine all words into a single list
all_words = positive_words + negative_words + neutral_words

# Function to count the occurrences of each word in the reviews
def count_words(reviews, words_list):
    words_count = Counter()
    for review in reviews:
        for word in words_list:
            words_count[word] += review.lower().split().count(word)
    return words_count

# Count the words in the reviews
reviews = df1['Desc'].tolist()
words_count = count_words(reviews, all_words)

# Create the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(words_count)

# Plot the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Word Cloud of T-Shirt Reviews')
plt.show()
